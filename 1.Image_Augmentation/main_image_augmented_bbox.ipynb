# %% [markdown]
# # Image Augmentation with Bounding Box
# Author : Bayu Aditya

# %%
import cv2
import json
import matplotlib.pyplot as plt

from Image_Augmentation_bbox import augmented_image_class

# %% [markdown]
# # Input -> image_array & dict_bbox

# %%
index = 60
LOC_DIR = 'image_plate_benchmark/image_bbox/'

# %%
with open('bbox.json') as f:
    data = json.load(f)

# %%
nama_file = data[index]['image_name']

# %% [markdown]
# ## for input

# %%
image = cv2.imread(LOC_DIR + nama_file)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
dict_bbox = data[index]
dict_bbox
# Out:
# {'bbox_char': [{'label': '3', 'x1': 84, 'x2': 98, 'y1': 3, 'y2': 27},
#   {'label': '0', 'x1': 54, 'x2': 68, 'y1': 4, 'y2': 27},
#   {'label': 'B', 'x1': 3, 'x2': 18, 'y1': 5, 'y2': 27},
#   {'label': '2', 'x1': 39, 'x2': 54, 'y1': 4, 'y2': 29},
#   {'label': '1', 'x1': 72, 'x2': 82, 'y1': 4, 'y2': 26},
#   {'label': 'S', 'x1': 113, 'x2': 129, 'y1': 3, 'y2': 27},
#   {'label': 'O', 'x1': 129, 'x2': 144, 'y1': 4, 'y2': 26},
#   {'label': 'O', 'x1': 144, 'x2': 160, 'y1': 4, 'y2': 28},
#   {'label': '0', 'x1': 144, 'x2': 160, 'y1': 4, 'y2': 28}],
#  'image_name': 'B2013SOO.jpg',
#  'plate_no': 'B2013SOO'}

# %% [markdown]
# # Final

# %%
final_class = augmented_image_class(image, dict_bbox)

# %%
final_class.parameter_mode
# Out:
# {'blur': ['very_low', 'low', 'med', 'high'],
#  'intensity': ['glow', 'dark'],
#  'noise': ['gaussian', 's&p', 'speckle'],
#  'rotate': ['left', 'right'],
#  'scale': ['small', 'big'],
#  'shear': ['left', 'right'],
#  'translate': ['up', 'down', 'left', 'right']}

# %%
final_dict = final_class.get_result()

# %%
final_dict['scale']['small']['bbox_char']
# Out:
# [{'label': '3', 'x1': 67, 'x2': 78, 'y1': 2, 'y2': 21},
#  {'label': '0', 'x1': 43, 'x2': 54, 'y1': 3, 'y2': 21},
#  {'label': 'B', 'x1': 2, 'x2': 14, 'y1': 4, 'y2': 21},
#  {'label': '2', 'x1': 31, 'x2': 43, 'y1': 3, 'y2': 23},
#  {'label': '1', 'x1': 57, 'x2': 65, 'y1': 3, 'y2': 20},
#  {'label': 'S', 'x1': 90, 'x2': 103, 'y1': 2, 'y2': 21},
#  {'label': 'O', 'x1': 103, 'x2': 115, 'y1': 3, 'y2': 20},
#  {'label': 'O', 'x1': 115, 'x2': 128, 'y1': 3, 'y2': 22},
#  {'label': '0', 'x1': 115, 'x2': 128, 'y1': 3, 'y2': 22}]

# %%
plt.imshow(final_dict['translate']['down']['images'])

# %%
final_class.view_result()
