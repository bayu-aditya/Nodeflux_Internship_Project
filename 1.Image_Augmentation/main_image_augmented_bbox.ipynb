# %% [markdown]
# # **Image Augmentation with Bounding Box**
# Author : Bayu Aditya

# %%
import cv2
import json
import matplotlib.pyplot as plt

from Image_Augmentation_bbox import augmented_image_class

# %% [markdown]
# # Input -> image_array & dict_bbox

# %%
index = 10
LOC_DIR = 'image_plate_benchmark/image_bbox/'

# %%
with open('bbox.json') as f:
    data = json.load(f)

# %%
nama_file = data[index]['image_name']

# %% [markdown]
# ## for input

# %%
image = cv2.imread(LOC_DIR + nama_file)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
dict_bbox = data[index]
dict_bbox
# Out:
# {'bbox_char': [{'label': 'U', 'x1': 148, 'x2': 162, 'y1': 5, 'y2': 29},
#   {'label': '6', 'x1': 40, 'x2': 55, 'y1': 3, 'y2': 28},
#   {'label': 'B', 'x1': 8, 'x2': 21, 'y1': 5, 'y2': 28},
#   {'label': '6', 'x1': 87, 'x2': 102, 'y1': 4, 'y2': 27},
#   {'label': '4', 'x1': 70, 'x2': 86, 'y1': 4, 'y2': 28},
#   {'label': 'R', 'x1': 131, 'x2': 146, 'y1': 5, 'y2': 29},
#   {'label': '9', 'x1': 56, 'x2': 69, 'y1': 4, 'y2': 28},
#   {'label': 'U', 'x1': 115, 'x2': 130, 'y1': 3, 'y2': 28}],
#  'image_name': 'B6946URU.jpg',
#  'plate_no': 'B6946URU'}

# %%
plt.imshow(image)

# %% [markdown]
# # Final

# %%
final_class = augmented_image_class(image, dict_bbox)

# %%
final_class.parameter_mode
# Out:
# {'blur': ['very_low', 'low', 'med', 'high'],
#  'intensity': ['glow', 'dark'],
#  'noise': ['gaussian', 's&p', 'speckle'],
#  'rotate': ['left', 'right'],
#  'rotate_shear': ['left', 'right'],
#  'scale': ['small', 'big'],
#  'shear': ['left', 'right'],
#  'translate': ['up', 'down', 'left', 'right']}

# %%
final_dict = final_class.get_result()

# %%
final_dict['rotate_shear']['left']['bbox_char']
# Out:
# [{'label': 'U', 'x1': 119, 'x2': 148, 'y1': 1, 'y2': 9},
#  {'label': '6', 'x1': 34, 'x2': 64, 'y1': 25, 'y2': 34},
#  {'label': 'B', 'x1': 10, 'x2': 38, 'y1': 33, 'y2': 41},
#  {'label': '6', 'x1': 71, 'x2': 101, 'y1': 14, 'y2': 23},
#  {'label': '4', 'x1': 57, 'x2': 89, 'y1': 18, 'y2': 27},
#  {'label': 'R', 'x1': 106, 'x2': 136, 'y1': 5, 'y2': 13},
#  {'label': '9', 'x1': 46, 'x2': 75, 'y1': 22, 'y2': 30},
#  {'label': 'U', 'x1': 91, 'x2': 123, 'y1': 8, 'y2': 17}]

# %%
plt.imshow(final_dict['translate']['down']['images'])

# %%
final_class.view_result()
